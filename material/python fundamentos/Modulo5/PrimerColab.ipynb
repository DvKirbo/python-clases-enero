# %%
import pandas as pd
import os
import shutil

# %%
# Generar un Dataframe de 0
lista = [
          ["Carlos", "Segundo ciclo", 17],
          ["Olga", "Primer ciclo", 14], 
          ["Arnold", "Primer ciclo", 18], 
          ["Maria", "Quinto ciclo", 8]
         ]
# nombre de columnas
columnas= ["nombre", "Ciclo", "Nota"]

df_notas = pd.DataFrame(lista, columns = columnas)
df_notas
# Out:
#    nombre          Ciclo  Nota
# 0  Carlos  Segundo ciclo    17
# 1    Olga   Primer ciclo    14
# 2  Arnold   Primer ciclo    18
# 3   Maria   Quinto ciclo     8

# %%
# leer uno de los archivos de ejemplo y mostrar sus primeros datos
path = '/content/sample_data/california_housing_test.csv'
df = pd.read_csv(path)

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir('/content/sample_data')
# Out:
# ['anscombe.json',
#  'README.md',
#  'california_housing_test.csv',
#  'mnist_test.csv',
#  'mnist_train_small.csv',
#  'california_housing_train.csv']

# %%
df_titanic = pd.read_csv('/content/drive/MyDrive/googleColab/src/titanic.csv')

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Generemos un df2 el cual contenple las columnas PassengerID, Survived, Pclass, Name, Sex, Age, Ticket y Cabin
columns = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket', 'Cabin']

df2 = df_titanic[columns]

# Generemos un df3, df4 : df3-> los que sobrevivieron, df4 = murieron

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df3 = df2[df2.Survived==1]
df4 = df2[df2.Survived==0]

# %%
df3['Survived'].unique() # ver valores unicos
# Out:
# array([1])

# %%
df3['Sex'].unique() # ver valores unicos
# Out:
# array(['female', 'male'], dtype=object)
